# %%
import matplotlib.pyplot as plt
from helper import *
from scipy import signal as sg
import numpy as np
from scipy import integrate
# %load_ext autoreload

# %autoreload 2

# %%
mySignal = 1 
file = "data/raw"+ str(mySignal) +".txt"

# Load the data 
signal = get_single_column_data(file)
time = create_time_axes(signal)

# %%
entree = filter(signal,5,1,False,True)

# %%
ksi = 0.69
omega0 = 200

num = [1]
den = [1/omega0**2,2*ksi/omega0, 1]
H = sg.TransferFunction(num, den)

t = np.arange(-1,10,0.01)
[t_ind, r_ind] = H.step()

plt.plot(t_ind,r_ind,label="Réponse Indicielle")
plt.grid()
plt.xlabel("Temps (s)")
plt.legend();

# %%
plt.plot(time, entree, label="Entree")

# %%
[t_s, sortie, xout] = H.output(entree,time)

plt.plot(t_s, sortie,label="Sortie")
plt.grid()
plt.xlabel("Temps (s)")
plt.legend();
